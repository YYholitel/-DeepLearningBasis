# %%
import torch
import numpy as np
sims = 1000
A = np.random.uniform(1,5,sims) # 使用uniform函数均匀分布
B =np.random.uniform(2,6,sims)
duration = A + B
print(A)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import torch
#       2 import numpy as np
#       3 sims = 1000
#       4 A = np.random.uniform(1,5,sims)
#
# File ~\PyCharmMiscProject\.venv\Lib\site-packages\torch\__init__.py:2291
#    2275 ################################################################################
#    2276 # Import most common subpackages
#    2277 ################################################################################
#    (...)   2282
#    2283 # needs to be before import torch.nn as nn to avoid circular dependencies
#    2284 from torch.autograd import (  # usort: skip
#    2285     enable_grad as enable_grad,
#    2286     inference_mode as inference_mode,
#    2287     no_grad as no_grad,
#    2288     set_grad_enabled as set_grad_enabled,
#    2289 )
# -> 2291 from torch import (
# ...
